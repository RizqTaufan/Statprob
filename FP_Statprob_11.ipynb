# %%
#   EXPLORATORY DATA ANALYSIS W/ HOUSING PRICE'S DATA PREDICITON

#   Colleagues:
#       Adi Satria Pangesetu  5027231043
#       Muhamad Rizq Taufan   5027231021
#       Thio Billy Amanysah   5027231007

#   Source Code: 
#       NeuralNine - https://youtu.be/Wqmtf9SA_kk?feature=shared
#       Modul StatProb - https://github.com/mocatfrio/statistics-probability/blob/main/final-project/Coba-EDA.ipynb
#   
#   Source Data:
#       Kaggle - https://www.kaggle.com/datasets/muhammadbinimran/housing-price-prediction-data/

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read data
df = pd.read_csv("hpd.csv")

# Check for null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SquareFeet    50000 non-null  int64
#  1   Bedrooms      50000 non-null  int64
#  2   Bathrooms     50000 non-null  int64
#  3   Neighborhood  50000 non-null  object
#  4   YearBuilt     50000 non-null  int64
#  5   Price         50000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 2.3+ MB

# %%
# No null values = no data preprocessing
# Show all data on histogram
df.hist(bins=100, grid=True)

# Advoid clipping onto one-another
plt.tight_layout()

# %%
# See correlation between house size and yearbuilt
plt.scatter(df.YearBuilt, df['SquareFeet'], s=1)
plt.title("YearBuilt x SquareFeet")
# Out:
# Text(0.5, 1.0, 'YearBuilt x SquareFeet')

# %%
# See correlation between price and neighborhood
df['Price'].hist(bins=100, grid=True, by=df['Neighborhood'])
plt.tight_layout()

# %%
# Price x Everything

plt.subplot(2,2,1) # (col, row, nth plot)
plt.scatter(df.YearBuilt, df['Price'], s=1)
plt.title("YearBuilt")

plt.subplot(2,2,2)
plt.scatter(df['SquareFeet'], df['Price'], s=1, c='g')
plt.title("SquareFeet")

plt.subplot(2,2,3)
plt.scatter(df['Bedrooms'], df['Price'], s=1)
plt.title("Bedrooms")

plt.subplot(2,2,4)
plt.scatter(df['Bathrooms'], df['Price'], s=1)
plt.title("Bathrooms")

plt.tight_layout()
